# %% [markdown]
# <a href="https://colab.research.google.com/github/JaganParab02/MODEL_TRAINING_FINSENSE/blob/main/FINSENSE_TRAINING_FILE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ==========================================
# CELL 1: Setup & Install Dependencies
# ==========================================

# 1. Clone your finalized GitHub repository
# !git clone https://github.com/JaganParab02/MODEL_TRAINING_FINSENSE.git
# %cd MODEL_TRAINING_FINSENSE

# 2. Install all required GPU & training libraries
# !pip install -r training/requirements_training.txt
# Out:
# Cloning into 'MODEL_TRAINING_FINSENSE'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (169/169), done.
# remote: Compressing objects: 100% (101/101), done.
# Receiving objects: 100% (169/169), 2.02 MiB | 721.00 KiB/s, done.
# remote: Total 169 (delta 65), reused 165 (delta 61), pack-reused 0 (from 0)
# Resolving deltas: 100% (65/65), done.
# /content/MODEL_TRAINING_FINSENSE
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 697.4/697.4 kB 27.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 28.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 20.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
# ...

# %%
# ==========================================
# CELL 2: Supervised Fine-Tuning (SFT) Demo
# ==========================================

# Run the end-to-end SFT evaluation and training script.
# This will evaluate the base model, train a LoRA adapter, and evaluate again.
# !git pull origin main

# !python training/colab_sft_demo.py --model Qwen/Qwen2.5-0.5B-Instruct --epochs 3.0
# Out:
# From https://github.com/JaganParab02/MODEL_TRAINING_FINSENSE
#  * branch            main       -> FETCH_HEAD
# Already up to date.
#
# ...
# Dependency Check
# ...
# torch: 2.10.0+cu128
# cuda available: True
# gpu: Tesla T4
# Generating train split: 30 examples [00:00, 15569.06 examples/s]
#
# ...
# Dataset Split
# ...
# Train examples: 24
# Eval examples: 6
# Prompt eval cases used: 6
# Env benchmark seeds: [42, 53, 64]
#
# ...
# Base Model Prompt Evaluation
# ...
# config.json: 100% 659/659 [00:00<00:00, 3.73MB/s]
# tokenizer_config.json: 7.30kB [00:00, 23.2MB/s]
# ...
# vocab.json: 2.78MB [00:00, 91.1MB/s]
# merges.txt: 1.67MB [00:00, 120MB/s]
# tokenizer.json: 7.03MB [00:00, 160MB/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors: 100% 988M/988M [00:07<00:00, 126MB/s]
# Loading weights: 100% 290/290 [00:01<00:00, 288.71it/s, Materializing param=model.norm.weight]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.21MB/s]
# ...
